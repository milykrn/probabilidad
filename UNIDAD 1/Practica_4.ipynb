# %% [markdown]
# <a href="https://colab.research.google.com/github/milykrn/probabilidad/blob/main/UNIDAD%201/Practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #*Probabilidad y estadistica*
#
# ##Unidad 1
# ###Practica 4. Diagramas de Cajas y bigotes
# ###Profesor: Dr. Jose Gabriel Rodriguez Rivas
# ###Alumna: Emily Karina Orozco Rodriguez

# %%
import random
import matplotlib.pyplot as ptl
from statistics import *

fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [81.93, 98.24, 59.91, 92.72, 88.07, 93.75, 89.21, 93.88, 86.34, 51.8, 50.13, 74.7, 83.83, 60.37, 91.65, 89.63, 89.33, 53.22, 53.79, 93.22, 86.89, 66.31, 79.15, 98.41, 67.65, 61.24, 95.53, 98.25, 78.67, 58.02, 67.09, 93.91, 68.19, 60.7, 50.1, 72.31, 56.08, 98.66, 93.53, 88.55, 90.05, 79.29, 62.59, 76.37, 89.67, 83.94, 87.5, 78.79, 52.86, 90.19, 68.73, 77.38, 60.73, 57.11, 81.99, 91.03, 58.22, 69.59, 94.27, 57.79, 68.96, 74.9, 61.63, 64.87, 63.52, 76.25, 57.52, 90.41, 95.21, 86.48, 80.0, 76.92, 84.86, 85.98, 70.27, 68.32, 93.21, 80.06, 99.72, 72.03, 96.24, 78.72, 71.83, 59.29, 94.22, 64.4, 91.81, 55.67, 64.63, 80.47, 72.0, 84.32, 51.18, 64.19, 54.17, 61.11, 79.17, 54.76, 84.46, 70.11]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [81.19, 90.52, 88.7, 83.51, 81.57, 67.62, 77.18, 73.4, 80.48, 80.91, 83.21, 62.44, 55.11, 91.02, 83.62, 46.27, 88.67, 69.65, 66.89, 76.59, 56.56, 75.92, 54.14, 44.54, 50.39, 74.83, 45.71, 61.89, 74.28, 58.95, 66.0, 91.51, 77.24, 70.17, 87.37, 51.55, 65.06, 46.07, 78.03, 91.51, 43.43, 70.55, 55.2, 81.19, 78.24, 89.66, 70.09, 42.22, 78.99, 88.42, 47.14, 84.89, 45.76, 69.96, 79.04, 49.25, 48.25, 45.65, 68.51, 71.95, 49.62, 57.61, 65.43, 46.24, 51.17, 66.92, 46.01, 70.87, 74.23, 58.56, 60.75, 60.7, 48.94, 51.45, 88.91, 61.51, 82.38, 71.67, 88.61, 89.46, 43.81, 67.79, 90.67, 48.84, 90.5, 84.48, 51.97, 48.66, 63.58, 40.08, 92.59, 84.46, 88.7, 70.39, 78.95, 91.78, 46.36, 70.39, 92.58, 84.35]

# %%
ptl.boxplot(fabrica1)
ptl.ylabel('producción en mts.')
ptl.title('producción de la fabrica 1')
ptl.show()

# %%
fig, (ax1, ax2) = ptl.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('producción de la fabrica 1')
bplot2 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('producción de la fabrica 2')
ptl.show()

# %%
fig,(ax1,ax2) = ptl.subplots(nrows=1,ncols=2,figsize=(9,4))
bplot1 = ax1.boxplot(fabrica1,vert=True,patch_artist=True)
ax1.set_title('producción de la fabrica 1')
bplot2 = ax2.boxplot(fabrica2,vert=True,patch_artist=True)
ax2.set_title('producción de la fabrica 2')
ptl.show()

# %%
fig,(ax1,ax2) = ptl.subplots(nrows=1,ncols=2,figsize=(9,5))
bplot1 = ax1.boxplot(fabrica1,vert=True,patch_artist=True)
ax1.set_title('producción de la fabrica 1')
ax1.set_ylim(30, 160)
bplot2 = ax2.boxplot(fabrica2,vert=True,patch_artist=True)
ax2.set_title('producción de la fabrica 2')
ax2.set_ylim(30, 160)
ptl.show()
